# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np

# Start coding here!

# %% [markdown]
# # Load the dataset and find the most common gender and birth country

# %%
nobel_prize_winner_df = pd.read_csv('data/nobel.csv')
nobel_prize_winner_df
# Out:
#      year    category                                              prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# ..    ...         ...                                                ...
# 995  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 996  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 997  2023  Literature                 The Nobel Prize in Literature 2023
# 998  2023       Peace                         The Nobel Peace Prize 2023
# 999  2023   Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# ...

# %% [markdown]
# ## Get the top_gender

# %%
nobel_prize_winner_df['sex'].value_counts().index[0]
# Get the most common gender and store it into the variable 'top_gender' 
top_gender = nobel_prize_winner_df['sex'].value_counts().index[0]
print(top_gender)
# Out:
# Male

# %% [markdown]
# ## Get the top_country

# %%
nobel_prize_winner_df['birth_country'].value_counts()
nobel_prize_winner_df['birth_country'].value_counts().index[0]
top_country = nobel_prize_winner_df['birth_country'].value_counts().index[0]
print(top_country)
# Out:
# United States of America

# %% [markdown]
# # Identify the decade with the highest ratio of US-born winners
# Which decade had the highest ratio of US-born Nobel Prize winners to total winners in all categories
#     Store this as an integer called 'max_decade_usa'

# %% [markdown]
# ## Create the US-born winners column

# %%
nobel_prize_winner_df['usa_born_winner'] = nobel_prize_winner_df['birth_country'] == 'United States of America'
nobel_prize_winner_df
# Out:
#      year    category                                              prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# ..    ...         ...                                                ...
# 995  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 996  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 997  2023  Literature                 The Nobel Prize in Literature 2023
# 998  2023       Peace                         The Nobel Peace Prize 2023
# 999  2023   Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# ...

# %%
nobel_prize_winner_df[nobel_prize_winner_df['usa_born_winner']==True]
# Out:
#      year   category                                              prize  \
# 35   1906      Peace                         The Nobel Peace Prize 1906
# 72   1912      Peace                         The Nobel Peace Prize 1912
# 79   1914  Chemistry                  The Nobel Prize in Chemistry 1914
# 95   1919      Peace                         The Nobel Peace Prize 1919
# 117  1923    Physics                    The Nobel Prize in Physics 1923
# ..    ...        ...                                                ...
# 987  2022  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 988  2022  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 990  2023   Medicine     The Nobel Prize in Physiology or Medicine 2023
# 995  2023  Chemistry                  The Nobel Prize in Chemistry 2023
# 999  2023  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# ...

# %% [markdown]
# ## Create the decade column

# %%
nobel_prize_winner_df['year'].unique()
# Out:
# array([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911,
#        1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922,
#        1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933,
#        1934, 1935, 1936, 1937, 1938, 1939, 1943, 1944, 1945, 1946, 1947,
#        1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958,
#        1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969,
#        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
# Convert the year column into a decade column 
# Use integer division by 10 and then multiple by 10
nobel_prize_winner_df['decade'] = (nobel_prize_winner_df['year']//10 ) * 10
nobel_prize_winner_df
# Out:
#      year    category                                              prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# ..    ...         ...                                                ...
# 995  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 996  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 997  2023  Literature                 The Nobel Prize in Literature 2023
# 998  2023       Peace                         The Nobel Peace Prize 2023
# 999  2023   Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# ...

# %%
nobel_prize_winner_df['decade'].unique()
nobel_prize_winner_df[nobel_prize_winner_df['decade'] == 1910]
# Out:
#     year    category                                           prize  \
# 57  1910   Chemistry               The Nobel Prize in Chemistry 1910
# 58  1910  Literature              The Nobel Prize in Literature 1910
# 59  1910    Medicine  The Nobel Prize in Physiology or Medicine 1910
# 60  1910       Peace                      The Nobel Peace Prize 1910
# 61  1910     Physics                 The Nobel Prize in Physics 1910
# 62  1911   Chemistry               The Nobel Prize in Chemistry 1911
# 63  1911  Literature              The Nobel Prize in Literature 1911
# 64  1911    Medicine  The Nobel Prize in Physiology or Medicine 1911
# 65  1911       Peace                      The Nobel Peace Prize 1911
# 66  1911       Peace                      The Nobel Peace Prize 1911
# 67  1911     Physics                 The Nobel Prize in Physics 1911
# 68  1912   Chemistry               The Nobel Prize in Chemistry 1912
# 69  1912   Chemistry               The Nobel Prize in Chemistry 1912
# ...

# %% [markdown]
# ## Finding the ratio

# %%
prop_usa_winners =nobel_prize_winner_df.groupby('decade',as_index=False)['usa_born_winner'].mean()

# %%
prop_usa_winners
# Out:
#     decade  usa_born_winner
# 0     1900         0.017544
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.250000
# 4     1940         0.302326
# 5     1950         0.291667
# 6     1960         0.265823
# 7     1970         0.317308
# 8     1980         0.319588
# 9     1990         0.403846
# 10    2000         0.422764
# 11    2010         0.314050
# 12    2020         0.360000

# %% [markdown]
# ## Identify the decade with the highest ratio of US-born winners

# %%
max_decade_usa = prop_usa_winners[prop_usa_winners['usa_born_winner'] == prop_usa_winners['usa_born_winner'].max()]['decade'].values[0]
print(max_decade_usa)
# Out:
# 2000

# %% [markdown]
# # Find the decade and category with the highest proportion of female laurates

# %%
nobel_prize_winner_df
# Out:
#      year    category                                              prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# ..    ...         ...                                                ...
# 995  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 996  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 997  2023  Literature                 The Nobel Prize in Literature 2023
# 998  2023       Peace                         The Nobel Peace Prize 2023
# 999  2023   Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# ...

# %% [markdown]
# ## Filtering for female winners

# %%
nobel_prize_winner_df['female_winners'] = nobel_prize_winner_df['sex'] == 'Female'

# %%
nobel_prize_winner_df[nobel_prize_winner_df['female_winners'] == True]
# Out:
#      year    category                                              prize  \
# 19   1903     Physics                    The Nobel Prize in Physics 1903
# 29   1905       Peace                         The Nobel Peace Prize 1905
# 51   1909  Literature                 The Nobel Prize in Literature 1909
# 62   1911   Chemistry                  The Nobel Prize in Chemistry 1911
# 128  1926  Literature                 The Nobel Prize in Literature 1926
# ..    ...         ...                                                ...
# 982  2022  Literature                 The Nobel Prize in Literature 2022
# 989  2023    Medicine     The Nobel Prize in Physiology or Medicine 2023
# 993  2023     Physics                    The Nobel Prize in Physics 2023
# 998  2023       Peace                         The Nobel Peace Prize 2023
# 999  2023   Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# ...

# %% [markdown]
# ## Group by two columns

# %%
female_winners =nobel_prize_winner_df.groupby(['decade','category'], as_index =False)['female_winners'].mean()
female_winners
# Out:
#     decade    category  female_winners
# 0     1900   Chemistry        0.000000
# 1     1900  Literature        0.100000
# 2     1900    Medicine        0.000000
# 3     1900       Peace        0.071429
# 4     1900     Physics        0.076923
# ..     ...         ...             ...
# 67    2020   Economics        0.111111
# 68    2020  Literature        0.500000
# 69    2020    Medicine        0.125000
# 70    2020       Peace        0.285714
# 71    2020     Physics        0.166667
#
# [72 rows x 3 columns]

# %%
female_winners.sort_values(by='female_winners',ascending=False).head(1)
# Out:
#     decade    category  female_winners
# 68    2020  Literature             0.5

# %%
max_female_decade_category = female_winners[female_winners['female_winners'] == female_winners['female_winners'].max()][['decade', 'category']]
max_female_decade_category
# Out:
#     decade    category
# 68    2020  Literature

# %% [markdown]
# ## Create a dictionary

# %%
max_female_dict = {max_female_decade_category['decade'].values[0]: max_female_decade_category['category'].values[0]}

# %%
print(max_female_dict)
# Out:
# {np.int64(2020): 'Literature'}

# %% [markdown]
# # Find first woman to win a Nobel Prize

# %%
female_winners_df =nobel_prize_winner_df[nobel_prize_winner_df['female_winners']]
first_female_winner_column = female_winners_df[female_winners_df['year']== female_winners_df['year'].min()]
first_female_winner_column
# Out:
#     year category                            prize  \
# 19  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            motivation prize_share  \
# 19  "in recognition of the extraordinary services ...         1/4
#
#     laureate_id laureate_type                    full_name  birth_date  \
# 19            6    Individual  Marie Curie, née Sklodowska  1867-11-07
#
#    birth_city  ...     sex organization_name organization_city  \
# 19     Warsaw  ...  Female               NaN               NaN
#
#    organization_country  death_date  death_city death_country usa_born_winner  \
# 19                  NaN  1934-07-04  Sallanches        France           False
#
#     decade  female_winners
# 19    1900            True
#
# [1 rows x 21 columns]

# %%
first_women_name = first_female_winner_column['full_name'].values[0]
first_women_category =first_female_winner_column['category'].values[0]
print(first_women_name)
print(first_women_category)
# Out:
# Marie Curie, née Sklodowska
# Physics

# %% [markdown]
# # Determine repeat winners

# %%
counts =nobel_prize_winner_df['full_name'].value_counts()
counts
# Out:
# full_name
# Comité international de la Croix Rouge (International Committee of the Red Cross)    3
# Frederick Sanger                                                                     2
# Marie Curie, née Sklodowska                                                          2
# Office of the United Nations High Commissioner for Refugees (UNHCR)                  2
# John Bardeen                                                                         2
#                                                                                     ..
# Louis Brus                                                                           1
# Aleksey Yekimov                                                                      1
# Jon Fosse                                                                            1
# Narges Mohammadi                                                                     1
# William Randal Cremer                                                                1
# ...

# %%
repeats = counts [counts > 2].index
repeats
repeat_list = list(repeats)
repeat_list
# Out:
# ['Comité international de la Croix Rouge (International Committee of the Red Cross)']
